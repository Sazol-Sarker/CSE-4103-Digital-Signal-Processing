# %% [markdown]
# **Importing python modules**

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import sympy

# %%
srate=256
t=np.arange(0.,1.,1/srate)
x1=5*np.sin(2*np.pi*2*t)
x2=2*np.sin(2*np.pi*4*t)
x3=7*np.sin(2*np.pi*6*t)
x4=x1+x2+x3

# %%
plt.figure(figsize=(24,14))
plt.suptitle('Constructing a wave with different Sine Waves',fontsize=40)
style.use('dark_background')
plt.subplot(2,2,1)
plt.plot(t,x1,linewidth=3)
plt.title("Sine wave of amplitude '5' and frequency '2' Hz",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,2)
plt.plot(t,x2,linewidth=3)
plt.title("Sine wave of amplitude '2' and frequency '4' Hz",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,3)
plt.plot(t,x3,linewidth=3)
plt.title("Sine wave of amplitude '7' and frequency '6' Hz",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,4)
plt.plot(t,x4,linewidth=3)
plt.title("Combined SineWave by adding all 3 wave",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.show()

# %%
srate=256
t=np.arange(0.,1.,1/srate)

SineWave=3*np.sin(2*np.pi*5*t)
CosineWave=3*np.cos(2*np.pi*5*t)
plt.figure(figsize=(24,14))
style.use('dark_background')

plt.plot(t,SineWave,'y',linewidth=3,label='SineWave')

plt.plot(t,CosineWave,'r',linewidth=3,label='CosineWave')


plt.xlabel('time '),plt.ylabel('Amplitude')
plt.title("Sine & Cosine wave comparison",fontsize=25)
plt.legend(fontsize=20)
plt.xlim([0,1])
plt.show()

# %%
srate=256
t=np.arange(0.,1.,1/srate)
x1=5*np.cos(2*np.pi*2*t)
x2=2*np.cos(2*np.pi*4*t)
x3=7*np.cos(2*np.pi*6*t)
x4=x1+x2+x3

# %%
#cosine
plt.figure(figsize=(24,14))
plt.suptitle('Constructing a wave with different Cosine Waves',fontsize=40)
style.use('dark_background')
plt.subplot(2,2,1)
plt.plot(t,x1,linewidth=3)
plt.title("Cosine wave of amplitude '5' and frequency '2' Hz",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,2)
plt.plot(t,x2,linewidth=3)
plt.title("Cosine wave of amplitude '2' and frequency '4' Hz",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,3)
plt.plot(t,x3,linewidth=3)
plt.title("Cosine wave of amplitude '7' and frequency '6' Hz",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,4)
plt.plot(t,x4,linewidth=3)
plt.title("Combined CosineWave by adding all 3 wave",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.show()

# %%
#DC
srate=256
t=np.arange(0.,1.,1/srate)
x1=np.sin(2*np.pi*2*t)
x2=2*np.cos(2*np.pi*4*t)
x3=x1+x2
DC=2
x4=DC+x1+x2

#plotting
plt.figure(figsize=(24,14))
plt.suptitle('Constructing a wave with different Sine Waves',fontsize=40)
style.use('dark_background')
plt.subplot(2,2,1)
plt.plot(t,x1,linewidth=3)
plt.title("Sinwave of amplitude '1' and frequency '2' Hz ",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,2)
plt.plot(t,x2,linewidth=3)
plt.title("Cosine wave of amplitude '2' and frequency '4' Hz ",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,3)
plt.plot(t,x3,linewidth=3)
plt.title("Comnined wave ",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,4)
plt.plot(t,x4,linewidth=3)
plt.title("DC with Combined ",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.show()

# %%
#coding fourier transform
srate=256
t=np.arange(0.,1.,1/srate)
amp=3
f=5
x=amp*np.sin(2*np.pi*f*t)

#initialize fourier coefficient
X=np.zeros(len(x),dtype=complex)

for freq in range(0,len(t)):
  #create complex sin wave & compute dot product with signal
  csw=np.exp(-1j*2*np.pi*freq*t)
  X[freq]=np.sum(np.multiply(x,csw))

#extract amplitude
amps=np.abs(X)/len(t)

# %%
print(amps.shape)
print(amps[22])
print(t.shape)
print(t)
# Out:
# (256,)
# 1.0551910960100406e-16
# (256,)
# [0.         0.00390625 0.0078125  0.01171875 0.015625   0.01953125
#  0.0234375  0.02734375 0.03125    0.03515625 0.0390625  0.04296875
#  0.046875   0.05078125 0.0546875  0.05859375 0.0625     0.06640625
#  0.0703125  0.07421875 0.078125   0.08203125 0.0859375  0.08984375
#  0.09375    0.09765625 0.1015625  0.10546875 0.109375   0.11328125
#  0.1171875  0.12109375 0.125      0.12890625 0.1328125  0.13671875
#  0.140625   0.14453125 0.1484375  0.15234375 0.15625    0.16015625
#  0.1640625  0.16796875 0.171875   0.17578125 0.1796875  0.18359375
#  0.1875     0.19140625 0.1953125  0.19921875 0.203125   0.20703125
#  0.2109375  0.21484375 0.21875    0.22265625 0.2265625  0.23046875
#  0.234375   0.23828125 0.2421875  0.24609375 0.25       0.25390625
#  0.2578125  0.26171875 0.265625   0.26953125 0.2734375  0.27734375
#  0.28125    0.28515625 0.2890625  0.29296875 0.296875   0.30078125
#  0.3046875  0.30859375 0.3125     0.31640625 0.3203125  0.32421875
#  0.328125   0.33203125 0.3359375  0.33984375 0.34375    0.34765625
#  0.3515625  0.35546875 0.359375   0.36328125 0.3671875  0.37109375
#  0.375      0.37890625 0.3828125  0.38671875 0.390625   0.39453125
#  0.3984375  0.40234375 0.40625    0.41015625 0.4140625  0.41796875
#  0.421875   0.42578125 0.4296875  0.43359375 0.4375     0.44140625
#  0.4453125  0.44921875 0.453125   0.45703125 0.4609375  0.46484375
#  0.46875    0.47265625 0.4765625  0.48046875 0.484375   0.48828125
#  0.4921875  0.49609375 0.5        0.50390625 0.5078125  0.51171875
#  0.515625   0.51953125 0.5234375  0.52734375 0.53125    0.53515625
#  0.5390625  0.54296875 0.546875   0.55078125 0.5546875  0.55859375
#  0.5625     0.56640625 0.5703125  0.57421875 0.578125   0.58203125
#  0.5859375  0.58984375 0.59375    0.59765625 0.6015625  0.60546875
#  0.609375   0.61328125 0.6171875  0.62109375 0.625      0.62890625
#  0.6328125  0.63671875 0.640625   0.64453125 0.6484375  0.65234375
#  0.65625    0.66015625 0.6640625  0.66796875 0.671875   0.67578125
#  0.6796875  0.68359375 0.6875     0.69140625 0.6953125  0.69921875
#  0.703125   0.70703125 0.7109375  0.71484375 0.71875    0.72265625
#  0.7265625  0.73046875 0.734375   0.73828125 0.7421875  0.74609375
#  0.75       0.75390625 0.7578125  0.76171875 0.765625   0.76953125
#  0.7734375  0.77734375 0.78125    0.78515625 0.7890625  0.79296875
#  0.796875   0.80078125 0.8046875  0.80859375 0.8125     0.81640625
#  0.8203125  0.82421875 0.828125   0.83203125 0.8359375  0.83984375
#  0.84375    0.84765625 0.8515625  0.85546875 0.859375   0.86328125
#  0.8671875  0.87109375 0.875      0.87890625 0.8828125  0.88671875
#  0.890625   0.89453125 0.8984375  0.90234375 0.90625    0.91015625
#  0.9140625  0.91796875 0.921875   0.92578125 0.9296875  0.93359375
#  0.9375     0.94140625 0.9453125  0.94921875 0.953125   0.95703125
#  0.9609375  0.96484375 0.96875    0.97265625 0.9765625  0.98046875
#  0.984375   0.98828125 0.9921875  0.99609375]

# %%
#plot signal & complex sine wave
plt.figure(figsize=(24,14))
style.use('dark_background')

plt.plot(t,x,linewidth=3,label='Signal with amp=3 & frequency=5 Hz')

plt.plot(t,3*np.real(csw),'r-',linewidth=3,label='Real part of csw')
#plt.title("Comnined wave ",fontsize=25)

plt.plot(t,x,3*np.imag(csw),'m-',linewidth=3,label='Imag part of csw')


plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.title("Signal modeling with complex Sine wave ",fontsize=25)
plt.xlim([0,1])
plt.legend(fontsize=15)
plt.show()

# %%
#plot signal & fourier transform

plt.figure(figsize=(24,14))
plt.suptitle('Signal & its fourier transform',fontsize=40)
style.use('dark_background')

plt.subplot(2,2,1)
plt.plot(t,x,linewidth=3)
plt.title("Sinwave of amplitude '3' and frequency '5' Hz ",fontsize=25)

plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,2)
markerline,stemlines,baseline=plt.stem(amps)
plt.setp(stemlines,'linewidth',3)
plt.title("Fourier transform of a signal ",fontsize=25)

plt.xlabel('Indices',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   from ipykernel import kernelapp as app

# %% [markdown]
# **Correcting amplitudes & converting indices to frequecies**

# %%
#cycle 11th lab

#Generating the signal
srate=256 #hz
t=np.arange(0.,1.,1/srate)
amp=3
f=5 #hz
x=amp*np.sin(2*np.pi*f*t)#signal

#initialize fourier coefficient
X=np.zeros(len(x),dtype=complex)

for freq in range(0,len(t)):
  #create complex sin wave & compute dot product with signal
  csw=np.exp(-1j*2*np.pi*freq*t)
  X[freq]=np.sum(np.multiply(x,csw))

#extract amplitude
amps=2*np.abs(X)/len(t)

#in the above line of code we multiply by 2 to incorporate the negative frequencies
#of complex sinusoidal

# %%
#converting indices to frequency
#there are 0 to 255 indices at which we generate the sine wave
#these are frequency indices
#not the frequency in hertz. Since we have n=256 indices including zeros
#theref0ore after (n/2)
#i.e 128 in
#in this case, we get the negative waveforms of the first 128 samples. It means after n=128,
#the frequencies are violating the nyquist criteria.
#thus in order to convert indices into hertz we need (n/2+1) or (n/2) linerarly spaced
#samples between zero &
#Nyquist (srate/2) as show below

import math
Nyquist=srate/2
Hz=np.linspace(0,Nyquist,math.floor(len(t)/2+1))

# %%
#Plotting the signal & its fourier transform
plt.figure(figsize=(24,12)) # set the size of figure
plt.suptitle('Signal & its fourier transform',fontsize=40)
style.use('dark_background')

plt.subplot(2,2,1)
plt.plot(t,x,linewidth=3)
plt.title("Signal of amplitude ;3; and frequency '5 Hz'",fontsize=25)
plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.subplot(2,2,2)
markerline,stemlines,baseline=plt.stem(Hz,amps[range(0,len(Hz))])
plt.setp(stemlines,'linewidth',3)
plt.xlim(0,10)
plt.ylim(0,5)
plt.title("Fourier transform of a signal",fontsize=25)
plt.xlabel('Frequency in Hz',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   del sys.path[0]

# %%
#task1
srate=256
t=np.arange(0.,1.,1/srate)
x1=3*np.sin(2*np.pi*2*t)
x2=5*np.sin(2*np.pi*4*t)
x3=7*np.sin(2*np.pi*6*t)
DC=5
x4=DC+x1+x2+x3

#plot signal & fourier transform

plt.figure(figsize=(24,14))
plt.suptitle('Signal & its fourier transform',fontsize=40)
style.use('dark_background')

plt.subplot(2,2,1)
plt.plot(t,x4,linewidth=3)
plt.title("Combined wave",fontsize=25)
plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)

#amps

#initialize fourier coefficient
X=np.zeros(len(x4),dtype=complex)

for freq in range(0,len(t)):
  #create complex sin wave & compute dot product with signal
  csw=np.exp(-1j*2*np.pi*freq*t)
  X[freq]=np.sum(np.multiply(x4,csw))

#extract amplitude
amps=2*np.abs(X)/len(t)

#in the above line of code we multiply by 2 to incorporate the negative frequencies
#of complex sinusoidal

import math
Nyquist=srate/2
Hz=np.linspace(0,Nyquist,math.floor(len(t)/2+1))

plt.subplot(2,2,2)
markerline,stemlines,baseline=plt.stem(amps)
plt.setp(stemlines,'linewidth',3)
plt.title("Fourier transform",fontsize=25)
plt.xlabel('Indices',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)


plt.subplot(2,2,4)
markerline,stemlines,baseline=plt.stem(Hz,amps[range(0,len(Hz))])
plt.setp(stemlines,'linewidth',3)
plt.xlim(0,15)
plt.ylim(0,10)
plt.title("Fourier transform",fontsize=25)
plt.xlabel('Frequency in Hz',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)
plt.show()

#energy density
energy=[]
for i in  range(0,len(X)):
      real=np.real(X[i])
      imag=np.imag(X[i])
      ampli=real**2+imag**2 
      print("Energy Density of C",i,ampli)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:51: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# Energy Density of C 0 1638400.0
# Energy Density of C 1 3.2311742677852644e-27
# Energy Density of C 2 147456.00000000006
# Energy Density of C 3 3.2311742677852644e-27
# Energy Density of C 4 409600.0
# Energy Density of C 5 1.6155871338926322e-27
# Energy Density of C 6 802816.0
# Energy Density of C 7 2.0194839173657902e-28
# Energy Density of C 8 4.942775172381422e-27
# Energy Density of C 9 8.27988406119974e-27
# Energy Density of C 10 1.231885189593132e-26
# Energy Density of C 11 7.270142102516845e-26
# Energy Density of C 12 1.420837791250975e-26
# Energy Density of C 13 2.731351998237231e-26
# Energy Density of C 14 1.182660269107341e-25
# Energy Density of C 15 5.711352953800125e-26
# Energy Density of C 16 2.980731884495388e-26
# Energy Density of C 17 2.128157395669037e-25
# Energy Density of C 18 1.729183104244458e-27
# Energy Density of C 19 2.6092363301090186e-26
# Energy Density of C 20 1.599496466837903e-25
# Energy Density of C 21 6.039834634734155e-26
# Energy Density of C 22 5.025043966257845e-26
# Energy Density of C 23 1.4445068693773513e-25
# Energy Density of C 24 2.7449480467535945e-25
# Energy Density of C 155 1.1218399926162328e-22
# Energy Density of C 156 2.680946756947955e-24
# Energy Density of C 157 4.840289764305167e-23
# Energy Density of C 158 1.2196578455622064e-26
# Energy Density of C 159 9.3205118964743e-25
# Energy Density of C 160 6.2554165273911676e-24
# Energy Density of C 161 2.6910824239627354e-24
# Energy Density of C 162 4.359568795222452e-24
# Energy Density of C 163 4.5705987509151615e-24
# Energy Density of C 164 4.6932180081237446e-24
# Energy Density of C 165 1.3563368720769304e-24
# Energy Density of C 166 5.527984208533764e-25
# Energy Density of C 167 1.1791877822886485e-23
# Energy Density of C 168 8.575169784988777e-24
# Energy Density of C 169 3.7046821096873875e-24
# Energy Density of C 170 5.195521541041537e-24
# Energy Density of C 171 7.099474017824542e-25
# Energy Density of C 172 8.575514615811972e-24
# Energy Density of C 173 2.5383603332185316e-24
# Energy Density of C 174 7.629065689125081e-23
# Energy Density of C 175 2.6787270872499376e-24
# Energy Density of C 176 8.842578544893888e-26
# Energy Density of C 177 3.237342706469072e-23
# Energy Density of C 178 4.907895755249809e-24
# Energy Density of C 179 7.698817007022995e-25
# Energy Density of C 180 1.512950965869223e-23
# Energy Density of C 181 2.872741904862709e-24
# Energy Density of C 182 1.5121201375638443e-25
# Energy Density of C 183 5.443926740347487e-24
# Energy Density of C 184 9.684738048315252e-24
# Energy Density of C 185 9.444684519412877e-24
# Energy Density of C 186 1.5105992137385782e-23
# Energy Density of C 187 2.4664461953767737e-24
# Energy Density of C 188 1.0272761277954236e-23
# Energy Density of C 189 2.5834664531459828e-23
# Energy Density of C 190 1.6116112749303183e-24
# Energy Density of C 191 7.374549421044656e-24
# Energy Density of C 192 1.763463843741742e-24
# Energy Density of C 193 7.301696538725685e-26
# Energy Density of C 194 2.933716908531767e-24
# Energy Density of C 195 6.402773760008238e-24
# Energy Density of C 196 9.727854029951011e-25
# Energy Density of C 197 7.312197855095987e-24
# Energy Density of C 198 3.543840865291423e-23
# Energy Density of C 199 2.1602331111640473e-23
# Energy Density of C 200 5.495404489806408e-23
# Energy Density of C 201 4.3355332289595444e-23
# Energy Density of C 202 4.218245152913013e-24
# Energy Density of C 203 1.1320821563462563e-23
# Energy Density of C 204 1.4302237538274197e-24
# Energy Density of C 205 1.1154158032548e-22
# Energy Density of C 206 5.7341431453519605e-25
# Energy Density of C 207 7.765043852168562e-25
# Energy Density of C 208 5.1142540766618e-24
# Energy Density of C 209 1.4157210391229972e-23
# Energy Density of C 210 2.105706414306447e-25
# Energy Density of C 211 5.135769508433843e-23
# Energy Density of C 212 1.1222351014892218e-24
# Energy Density of C 213 3.143685057446049e-24
# Energy Density of C 214 1.1170170232594564e-23
# Energy Density of C 215 3.9981439870635536e-23
# Energy Density of C 216 2.0497709104797347e-23
# Energy Density of C 217 2.1020934313605346e-25
# Energy Density of C 218 2.2244749456138067e-24
# Energy Density of C 219 1.812527521058506e-23
# Energy Density of C 220 8.632647866872603e-26
# Energy Density of C 221 5.561661548324645e-23
# Energy Density of C 222 2.3956866343558973e-23
# Energy Density of C 223 5.422357311046481e-23
# Energy Density of C 224 8.076674330179519e-24
# Energy Density of C 225 2.1274235183689097e-23
# Energy Density of C 226 2.5355228005424516e-24
# Energy Density of C 227 4.028790266876781e-23
# Energy Density of C 228 4.690838322921484e-24
# Energy Density of C 229 7.430754182819843e-25
# Energy Density of C 230 4.666860804495249e-23
# Energy Density of C 231 1.3793763831178605e-23
# Energy Density of C 232 7.265188579885002e-25
# Energy Density of C 233 4.2385762283650024e-23
# Energy Density of C 234 1.5925602840692308e-25
# Energy Density of C 235 4.937196415852433e-24
# Energy Density of C 236 1.4165698657829666e-24
# Energy Density of C 237 8.031250881092181e-24
# Energy Density of C 238 3.364630679173025e-23
# Energy Density of C 239 2.3305475495125396e-24
# Energy Density of C 240 8.026457765313546e-24
# Energy Density of C 241 7.683644056371974e-24
# Energy Density of C 242 5.939040299152256e-24
# Energy Density of C 243 1.3099382429993198e-24
# Energy Density of C 244 2.559711014479711e-22
# Energy Density of C 245 3.408535442827915e-23
# Energy Density of C 246 1.2879059890052211e-23
# Energy Density of C 247 1.4684152239306828e-22
# Energy Density of C 248 1.8553624335567026e-22
# Energy Density of C 249 4.84907371076328e-22
# Energy Density of C 250 802816.0000000201
# Energy Density of C 251 1.247233267365112e-23
# Energy Density of C 252 409600.00000000483
# Energy Density of C 253 1.6155871338926322e-25
# Energy Density of C 254 147456.0000000005
# Energy Density of C 255 1.2147276542311923e-22

# %%
#task2-ct3 Q1 solution
xn={-2,1,2}
N=3
#plot signal & fourier transform

plt.figure(figsize=(24,14))
plt.suptitle('Signal',fontsize=40)
style.use('dark_background')

plt.subplot(2,2,1)
#t1=np.arange(0,3)
plt.plot(t1,xn,linewidth=3)
plt.title("Signal",fontsize=25)
plt.xlabel('time in sec',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)



#initialize fourier coefficient
X=np.zeros(len(xn),dtype=complex)

csw=np.exp(-1j*2*np.pi*t*)
csw=csw/N
for i in range(0,len(t)):
  #create complex sin wave & compute dot product with signal
  csw=np.exp(-1j*2*np.pi*i*)
  csw=csw/N
  X[freq]=np.sum(np.multiply(x4,csw))

#extract amplitude
amps=2*np.abs(X)/len(t)

#in the above line of code we multiply by 2 to incorporate the negative frequencies
#of complex sinusoidal

import math
Nyquist=srate/2
Hz=np.linspace(0,Nyquist,math.floor(len(t)/2+1))


plt.subplot(2,2,2)
markerline,stemlines,baseline=plt.stem(amps)
plt.setp(stemlines,'linewidth',3)
plt.title("Fourier transform",fontsize=25)
plt.xlabel('Indices',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)


plt.subplot(2,2,4)
markerline,stemlines,baseline=plt.stem(Hz,amps[range(0,len(Hz))])
plt.setp(stemlines,'linewidth',3)
plt.xlim(0,15)
plt.ylim(0,10)
plt.title("Fourier transform",fontsize=25)
plt.xlabel('Frequency in Hz',fontsize=20)
plt.ylabel('Amplitude',fontsize=20)
plt.show()
